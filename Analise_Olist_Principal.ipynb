# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_orders = pd.read_csv('data/olist_orders_dataset.csv')
df_items = pd.read_csv('data/olist_order_items_dataset.csv')
df_payments = pd.read_csv('data/olist_order_payments_dataset.csv')
df_customers = pd.read_csv('data/olist_customers_dataset.csv')

# %%
colunas_data = [
    'order_purchase_timestamp', 
    'order_approved_at', 
    'order_delivered_carrier_date', 
    'order_delivered_customer_date', 
    'order_estimated_delivery_date'
]

for col in colunas_data:
    df_orders[col] = pd.to_datetime(df_orders[col])

# %%
df_orders = df_orders.rename(columns={
    'order_id': 'ID_Pedido',
    'customer_id': 'ID_Cliente',
    'order_status': 'Status_Pedido',
    'order_purchase_timestamp': 'Data_Compra',
    'order_approved_at': 'Data_Aprovacao',
    'order_delivered_carrier_date': 'Data_Envio_Transportadora',
    'order_delivered_customer_date': 'Data_Entrega',
    'order_estimated_delivery_date': 'Data_Previsao_Entrega'
})

# %%
traducao_status = {
    'delivered': 'entregue',
    'shipped': 'enviado',
    'canceled': 'cancelado',
    'unavailable': 'indisponivel',
    'invoiced': 'faturado',
    'processing': 'em_processamento',
    'created': 'criado',
    'approved': 'aprovado'
}

df_orders['Status_Pedido'] = df_orders['Status_Pedido'].replace(traducao_status)


print("--- Distribuição de Status em Português ---")
print(df_orders['Status_Pedido'].value_counts(normalize=True))
# Out:
# --- Distribuição de Status em Português ---
# Status_Pedido
# entregue            0.970203
# enviado             0.011132
# cancelado           0.006285
# indisponivel        0.006124
# faturado            0.003158
# em_processamento    0.003027
# criado              0.000050
# aprovado            0.000020
# Name: proportion, dtype: float64

# %%
# CÉLULA NOVA (INSERIR ANTES DA CÉLULA 6)
# KPI: Taxa de Cancelamento (Conversão do Pedido)
# Requisito: "Conversão de pagamento: taxa de Confirmado vs Cancelado"

total_pedidos_brutos = len(df_orders)
pedidos_cancelados = df_orders[df_orders['Status_Pedido'] == 'cancelado'].shape[0]
taxa_cancelamento = (pedidos_cancelados / total_pedidos_brutos) * 100

print(f"--- KPI de Conversão/Integridade ---")
print(f"Total de Pedidos Brutos: {total_pedidos_brutos}")
print(f"Pedidos Cancelados: {pedidos_cancelados}")
print(f"Taxa de Cancelamento Global: {taxa_cancelamento:.2f}%")
print("-" * 30)
# Out:
# --- KPI de Conversão/Integridade ---
# Total de Pedidos Brutos: 99441
# Pedidos Cancelados: 625
# Taxa de Cancelamento Global: 0.63%
# ------------------------------

# %%
import matplotlib.pyplot as plt

# CÉLULA: VISUALIZAÇÃO COMPACTA DE INTEGRIDADE
# Estilo: KPI Card Horizontal (Barra de Saúde)

# Dados
taxa = taxa_cancelamento  # 0.63%
taxa_sucesso = 100 - taxa # 99.37%

# Configuração da Figura (Bem baixa e larga: 8x1.5 polegadas)
plt.figure(figsize=(8, 1.5))
ax = plt.gca()

# 1. A Barra de Fundo (Representando 100% dos pedidos)
# Cor: Verde Suave (Sucesso)
plt.barh(0, 100, color='#2ecc71', height=0.6, label='Pedidos Válidos')

# 2. A Barra de Cancelamento (Representando o 0.63%)
# Cor: Vermelho (Problema) - Desenhada por cima
plt.barh(0, taxa, color='#e74c3c', height=0.6, label='Cancelados')

# 3. Textos (O destaque principal)
# Texto do Cancelamento (Vermelho)
plt.text(taxa + 1, 0, f"Cancelados: {taxa:.2f}%", 
         fontsize=16, fontweight='bold', color='#c0392b', va='center')

# Texto dos Válidos (Verde - na ponta direita)
plt.text(99, 0, f"Aprovados: {taxa_sucesso:.2f}%", 
         fontsize=12, fontweight='bold', color='white', ha='right', va='center')

# 4. Limpeza Total (Remove eixos, bordas, números)
plt.xlim(0, 100)
plt.axis('off') # Remove o quadrado em volta
plt.title("Saúde da Base de Dados (Proporção Real)", fontsize=12, loc='left', color='gray')

plt.tight_layout()
plt.show()

# %%
# Célula 6: Filtragem de Status

status_invalidos = ['cancelado', 'indisponivel']

df_orders_filtrado = df_orders[~df_orders['Status_Pedido'].isin(status_invalidos)].copy()


print(f"Total de Pedidos Original: {len(df_orders)}")
print(f"Total de Pedidos Válidos (Filtrados): {len(df_orders_filtrado)}")


print("\nVerificação dos Status Após Filtragem:")
print(df_orders_filtrado['Status_Pedido'].value_counts(normalize=True))
# Out:
# Total de Pedidos Original: 99441
# Total de Pedidos Válidos (Filtrados): 98207
#
# Verificação dos Status Após Filtragem:
# Status_Pedido
# entregue            0.982394
# enviado             0.011272
# faturado            0.003197
# em_processamento    0.003065
# criado              0.000051
# aprovado            0.000020
# Name: proportion, dtype: float64

# %%
# Célula 7: Preparação e Merge 1 (Clientes e Pedidos)

# 1. Renomear colunas do DataFrame de Clientes (df_customers)
df_customers = df_customers.rename(columns={
    'customer_id': 'ID_Cliente',
    'customer_unique_id': 'ID_Cliente_Unico',
    'customer_zip_code_prefix': 'CEP_Cliente',
    'customer_city': 'Cidade_Cliente',
    'customer_state': 'UF_Cliente'
})

# 2. Executar o Merge
# Tipo de merge (how): 'left', garantindo que todos os nossos 98.207 pedidos filtrados sejam mantidos.
df_base = pd.merge(
    df_orders_filtrado, 
    df_customers[['ID_Cliente', 'CEP_Cliente', 'Cidade_Cliente', 'UF_Cliente', 'ID_Cliente_Unico']], 
    on='ID_Cliente', 
    how='left'
)

# 3. Inspeção
print("--- Base de Pedidos após Merge com Clientes (df_base) ---")
df_base.info()
# Out:
# --- Base de Pedidos após Merge com Clientes (df_base) ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98207 entries, 0 to 98206
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID_Pedido                  98207 non-null  object
#  1   ID_Cliente                 98207 non-null  object
#  2   Status_Pedido              98207 non-null  object
#  3   Data_Compra                98207 non-null  datetime64[ns]
#  4   Data_Aprovacao             98188 non-null  datetime64[ns]
#  5   Data_Envio_Transportadora  97583 non-null  datetime64[ns]
#  6   Data_Entrega               96470 non-null  datetime64[ns]
#  7   Data_Previsao_Entrega      98207 non-null  datetime64[ns]
#  8   CEP_Cliente                98207 non-null  int64
#  9   Cidade_Cliente             98207 non-null  object
#  10  UF_Cliente                 98207 non-null  object
# ...

# %%
# Célula 8: Criação da Base Logística (Apenas pedidos entregues)

# 1. Filtra a base para remover todos os pedidos onde a Data_Entrega é Nula (NaN)
df_logistica = df_base[df_base['Data_Entrega'].notna()].copy()

# 2. Reinspeção
print(f"Total de Pedidos Válidos (df_base): {len(df_base)}")
print(f"Total de Pedidos Entregues (df_logistica): {len(df_logistica)}")

# 3. Criação dos KPIs de Tempo (Feature Engineering - Início)

# Prazo de Entrega
df_logistica['Prazo_Entrega_Dias'] = (
    df_logistica['Data_Entrega'] - df_logistica['Data_Compra']
).dt.days

# Atraso em dias
df_logistica['Atraso_Dias'] = (
    df_logistica['Data_Entrega'] - df_logistica['Data_Previsao_Entrega']
).dt.days

# Criação da Flag de Atraso (is_late)
# Se a entrega foi DEPOIS da previsão, Atraso_Dias > 0, logo é Atrasado
df_logistica['Atrasado'] = (df_logistica['Atraso_Dias'] > 0).astype(int)

# 4. Exibe a Média Imediata (Insight Rápido)
print(f"\nMédia de Prazo de Entrega (dias): {df_logistica['Prazo_Entrega_Dias'].mean():.2f}")
print(f"Proporção de Pedidos Atrasados: {df_logistica['Atrasado'].mean():.2%}")
# Out:
# Total de Pedidos Válidos (df_base): 98207
# Total de Pedidos Entregues (df_logistica): 96470
#
# Média de Prazo de Entrega (dias): 12.09
# Proporção de Pedidos Atrasados: 6.77%

# %%
# Célula 9: Agregação e Merge 2 (Itens) 
# 1. Agrupar df_items por ID_Pedido e somar os valores para obter o total do pedido
df_itens_agregado = df_items.groupby('order_id').agg(
    Subtotal=('price', 'sum'),
    Frete_Total=('freight_value', 'sum'),
    Qtd_Itens=('order_item_id', 'count'),
    # CORREÇÃO: Adiciona ID_Produto do primeiro item para o merge de categoria na Célula 27
    ID_Produto=('product_id', 'first')
).reset_index()

# 2. Renomear a chave para o merge
df_itens_agregado = df_itens_agregado.rename(columns={'order_id': 'ID_Pedido'})

# 3. Merge 2: Juntar a base mestra com os dados agregados dos itens
df_base = pd.merge(df_base, df_itens_agregado, on='ID_Pedido', how='left')

# 4. Inspeção para verificar as novas colunas
print("\n--- Base Mestra após Merge com Itens (df_base) ---")
print(df_base[['ID_Pedido', 'Subtotal', 'Frete_Total', 'Qtd_Itens', 'ID_Produto']].head())
# Out:
# --- Base Mestra após Merge com Itens (df_base) ---
#                           ID_Pedido  Subtotal  Frete_Total  Qtd_Itens  \
# 0  e481f51cbdc54678b7cc49136f2d6af7     29.99         8.72        1.0
# 1  53cdb2fc8bc7dce0b6741e2150273451    118.70        22.76        1.0
# 2  47770eb9100c2d0c44946d9cf07ec65d    159.90        19.22        1.0
# 3  949d5b44dbf5de918fe9c16f97b45f8a     45.00        27.20        1.0
# 4  ad21c59c0840e6cb83a9ceb5573f8159     19.90         8.72        1.0
#
#                          ID_Produto
# 0  87285b34884572647811a353c7ac498a
# 1  595fac2a385ac33a80bd5114aec74eb8
# 2  aa4383b373c6aca5d8797843e5594415
# 3  d0b61bfb1de832b15ba9d266ca96e5b0
# 4  65266b2da20d04dbe00c5c2d3bb7859e

# %%
# Célula 10: Agregação e Merge 3 (Pagamentos)

# 1. Renomear e selecionar colunas necessárias do df_payments
df_pagamentos_prep = df_payments.rename(columns={
    'order_id': 'ID_Pedido',
    'payment_type': 'Tipo_Pagamento',
    'payment_value': 'Valor_Pago'
})[['ID_Pedido', 'Tipo_Pagamento', 'Valor_Pago', 'payment_installments']]

# 2. Agrupar df_pagamentos_prep por ID_Pedido
df_pagamentos_agregado = df_pagamentos_prep.groupby('ID_Pedido').agg(
    Valor_Total_Pago=('Valor_Pago', 'sum'),
    Tipo_Pagamento_Principal=('Tipo_Pagamento', lambda x: x.mode()[0]), 
    Total_Parcelas=('payment_installments', 'sum')
).reset_index()

# 3. Merge 3: Juntar a base mestra com os dados agregados dos pagamentos
df_base = pd.merge(df_base, df_pagamentos_agregado, on='ID_Pedido', how='left')

# 4. Inspeção final da Base Mestra (apenas colunas financeiras)
print("--- Colunas Financeiras Finais no df_base ---")
print(df_base[['Subtotal', 'Frete_Total', 'Valor_Total_Pago', 'Tipo_Pagamento_Principal']].head())
# Out:
# --- Colunas Financeiras Finais no df_base ---
#    Subtotal  Frete_Total  Valor_Total_Pago Tipo_Pagamento_Principal
# 0     29.99         8.72             38.71                  voucher
# 1    118.70        22.76            141.46                   boleto
# 2    159.90        19.22            179.12              credit_card
# 3     45.00        27.20             72.20              credit_card
# 4     19.90         8.72             28.62              credit_card

# %%
# Célula 11: Feature Engineering Financeira (AGORA COM PROPORÇÃO DE FRETE)
# 1. Cálculo do Desconto (em Reais)
df_base['Desconto_Abs'] = (df_base['Subtotal'].fillna(0) + df_base['Frete_Total'].fillna(0)) - df_base['Valor_Total_Pago'].fillna(0)
# 2. Formalização da Receita Bruta (Valor que o cliente pagou)
df_base['Receita_Bruta'] = df_base['Valor_Total_Pago'].fillna(0)
# 3. CÁLCULO DA PROPORÇÃO DO FRETE (KPI para P2)
# É a proporção do valor do frete em relação ao valor do produto + frete
df_base['Proporcao_Frete_Perc'] = (df_base['Frete_Total'] / (df_base['Subtotal'] + df_base['Frete_Total'] + 0.001)) * 100
# 4. Cálculo do Ticket Médio por pedido
df_base['Ticket_Medio'] = df_base['Valor_Total_Pago'].fillna(0)
# 5. Cálculo do Desconto Percentual
df_base['Desconto_Perc'] = (df_base['Desconto_Abs'] / (df_base['Subtotal'] + df_base['Frete_Total'] + 0.001)) * 100
# 6. Inspeção dos resultados
print("--- Novos KPIs Financeiros (Primeiras 5 linhas) ---")
if not df_base.empty and all(col in df_base.columns for col in ['Receita_Bruta', 'Desconto_Abs', 'Proporcao_Frete_Perc', 'Desconto_Perc', 'Ticket_Medio']):
    print(df_base[['Receita_Bruta', 'Desconto_Abs', 'Proporcao_Frete_Perc', 'Desconto_Perc', 'Ticket_Medio']].head())
# Out:
# --- Novos KPIs Financeiros (Primeiras 5 linhas) ---
#    Receita_Bruta  Desconto_Abs  Proporcao_Frete_Perc  Desconto_Perc  \
# 0          38.71  0.000000e+00             22.525897   0.000000e+00
# 1         141.46  0.000000e+00             16.089240   0.000000e+00
# 2         179.12  0.000000e+00             10.730177   0.000000e+00
# 3          72.20  0.000000e+00             37.672608   0.000000e+00
# 4          28.62 -3.552714e-15             30.467140  -1.241296e-14
#
#    Ticket_Medio
# 0         38.71
# 1        141.46
# 2        179.12
# 3         72.20
# 4         28.62

# %%
# Célula 12: Arredondamento e Ajuste Fino do Desconto

# 1. Arredonda o desconto absoluto para 2 casas decimais.
df_base['Desconto_Abs'] = df_base['Desconto_Abs'].round(2)

# 2. Garante que qualquer valor negativo residual seja tratado como zero (sem 'desconto negativo').
df_base.loc[df_base['Desconto_Abs'] < 0, 'Desconto_Abs'] = 0

# 3. Recálculo do Desconto Percentual com o Desconto_Abs corrigido.
df_base['Desconto_Perc'] = (df_base['Desconto_Abs'] / (df_base['Subtotal'] + df_base['Frete_Total'] + 0.001)) * 100

# 4. Inspeção (filtrando pedidos com desconto > 0 para ver o efeito)
print("--- Verificação dos Descontos Corrigidos (Apenas pedidos com desconto) ---")
print(df_base[df_base['Desconto_Abs'] > 0][['Subtotal', 'Frete_Total', 'Valor_Total_Pago', 'Desconto_Abs', 'Desconto_Perc']].head())
# Out:
# --- Verificação dos Descontos Corrigidos (Apenas pedidos com desconto) ---
#       Subtotal  Frete_Total  Valor_Total_Pago  Desconto_Abs  Desconto_Perc
# 305      721.5       277.00            998.49          0.01       0.001002
# 462      168.0        50.02            218.00          0.02       0.009173
# 861      248.0         9.36            257.34          0.02       0.007771
# 1970     330.0        20.41            333.91         16.50       4.708756
# 2334      49.0         7.60             51.70          4.90       8.657091

# %%
# Célula 13: Identificação de Outliers em Receita Bruta (Método IQR)

# 1. Definir a coluna a ser analisada
coluna_outlier = 'Receita_Bruta'

# 2. Calcular o Primeiro Quartil (Q1) e o Terceiro Quartil (Q3)
Q1 = df_base[coluna_outlier].quantile(0.25)
Q3 = df_base[coluna_outlier].quantile(0.75)
IQR = Q3 - Q1

# 3. Definir os limites inferior e superior para Outliers
# Limite Superior = Q3 + 1.5 * IQR
# Limite Inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR
limite_inferior = Q1 - 1.5 * IQR

# 4. Contar e inspecionar os outliers (valores acima do limite superior)
outliers_count = df_base[df_base[coluna_outlier] > limite_superior].shape[0]

print(f"--- Análise de Outliers para {coluna_outlier} ---")
print(f"Q1 (25%): R$ {Q1:.2f}")
print(f"Q3 (75%): R$ {Q3:.2f}")
print(f"IQR: R$ {IQR:.2f}")
print(f"Limite Superior (Outlier): R$ {limite_superior:.2f}")
print(f"Total de Outliers acima do Limite: {outliers_count} pedidos")
print(f"Representa {outliers_count / len(df_base) * 100:.2f}% dos dados")
# Out:
# --- Análise de Outliers para Receita_Bruta ---
# Q1 (25%): R$ 62.00
# Q3 (75%): R$ 176.75
# IQR: R$ 114.75
# Limite Superior (Outlier): R$ 348.88
# Total de Outliers acima do Limite: 7735 pedidos
# Representa 7.88% dos dados

# %%
# Célula 14: Implementação do Capping (Limite de Outlier)

# O limite superior calculado foi R$ 348.88
LIMITE_SUPERIOR_RECEITA = 348.88

# Aplicar o capping: onde a Receita_Bruta for maior que o limite,
# substituímos o valor da Receita_Bruta (e Ticket_Medio) pelo limite.
df_base.loc[df_base['Receita_Bruta'] > LIMITE_SUPERIOR_RECEITA, 'Receita_Bruta'] = LIMITE_SUPERIOR_RECEITA
df_base.loc[df_base['Receita_Bruta'] > LIMITE_SUPERIOR_RECEITA, 'Ticket_Medio'] = LIMITE_SUPERIOR_RECEITA


# Verificação: Exibe a nova média (deve ser menor que a média original)
nova_media = df_base['Receita_Bruta'].mean()
print(f"Novo Ticket Médio (Receita Bruta após capping): R$ {nova_media:.2f}")
# Out:
# Novo Ticket Médio (Receita Bruta após capping): R$ 133.62

# %%
# Célula 15: Identificação de Outliers em Frete_Total (Método IQR)

# 1. Definir a coluna a ser analisada
coluna_outlier_frete = 'Frete_Total'

# 2. Calcular o Primeiro Quartil (Q1) e o Terceiro Quartil (Q3)
Q1_frete = df_base[coluna_outlier_frete].quantile(0.25)
Q3_frete = df_base[coluna_outlier_frete].quantile(0.75)
IQR_frete = Q3_frete - Q1_frete

# 3. Definir os limites inferior e superior
limite_superior_frete = Q3_frete + 1.5 * IQR_frete
limite_inferior_frete = Q1_frete - 1.5 * IQR_frete

# 4. Contar e inspecionar os outliers (valores acima do limite superior)
outliers_frete_count = df_base[df_base[coluna_outlier_frete] > limite_superior_frete].shape[0]

print(f"--- Análise de Outliers para {coluna_outlier_frete} ---")
print(f"Q1 (25%): R$ {Q1_frete:.2f}")
print(f"Q3 (75%): R$ {Q3_frete:.2f}")
print(f"Limite Superior (Outlier): R$ {limite_superior_frete:.2f}")
print(f"Total de Outliers acima do Limite: {outliers_frete_count} pedidos")
print(f"Representa {outliers_frete_count / len(df_base) * 100:.2f}% dos dados")
# Out:
# --- Análise de Outliers para Frete_Total ---
# Q1 (25%): R$ 13.86
# Q3 (75%): R$ 24.05
# Limite Superior (Outlier): R$ 39.34
# Total de Outliers acima do Limite: 9879 pedidos
# Representa 10.06% dos dados

# %%
# Célula 16: Implementação do Capping no Frete_Total

# O limite superior calculado foi R$ 39.34
LIMITE_SUPERIOR_FRETE = 39.34

# Aplicar o capping: onde o Frete_Total for maior que o limite,
# substituímos o valor pelo limite (R$ 39.34).
df_base.loc[df_base['Frete_Total'] > LIMITE_SUPERIOR_FRETE, 'Frete_Total'] = LIMITE_SUPERIOR_FRETE

# Verificação: Exibe o novo Custo Médio de Frete
nova_media_frete = df_base['Frete_Total'].mean()
print(f"Novo Custo Médio de Frete (após capping): R$ {nova_media_frete:.2f}")
# Out:
# Novo Custo Médio de Frete (após capping): R$ 19.96

# %%
# Célula 17: Trimming (Limpeza de Espaços) - Finalizando a Limpeza Estrutural

colunas_texto = [
    'Status_Pedido', 
    'Cidade_Cliente', 
    'UF_Cliente', 
    'Tipo_Pagamento_Principal'
]

# Aplicar o método .str.strip() para remover espaços nas extremidades
for col in colunas_texto:
    # A função .str.strip() só funciona em colunas do tipo 'object' (texto)
    df_base[col] = df_base[col].str.strip()

print("Trimming de Texto concluído. Colunas categóricas prontas para o agrupamento (EDA).")
# Out:
# Trimming de Texto concluído. Colunas categóricas prontas para o agrupamento (EDA).

# %%
# Célula 18: Inspeção da Limpeza de Variáveis Categóricas (Tipo de Pagamento)

# O argumento 'normalize=True' mostra a proporção (porcentagem) de cada tipo de pagamento
print("Distribuição de Tipos de Pagamento:")
print(df_base['Tipo_Pagamento_Principal'].value_counts(normalize=True))
# Out:
# Distribuição de Tipos de Pagamento:
# Tipo_Pagamento_Principal
# credit_card    0.766267
# boleto         0.198959
# voucher        0.019357
# debit_card     0.015417
# Name: proportion, dtype: float64

# %%
# CÉLULA 19: MIX DE PAGAMENTO (VISUAL CLARO)
# 1. Preparar dados (Transformar em %)
pagamento_counts = df_base['Tipo_Pagamento_Principal'].value_counts(normalize=True) * 100
df_pag = pagamento_counts.reset_index()
df_pag.columns = ['Meio de Pagamento', 'Porcentagem']

# Traduzir nomes
mapa_nomes = {'credit_card': 'Cartão de Crédito', 'boleto': 'Boleto', 'voucher': 'Voucher', 'debit_card': 'Débito'}
df_pag['Meio de Pagamento'] = df_pag['Meio de Pagamento'].replace(mapa_nomes)

# 2. Plotagem
plt.figure(figsize=(10, 5))
ax = sns.barplot(x='Porcentagem', y='Meio de Pagamento', data=df_pag, palette='viridis')

# 3. Adicionar os números na frente da barra (ex: "76.6%")
for i, v in enumerate(df_pag['Porcentagem']):
    ax.text(v + 1, i, f"{v:.1f}%", va='center', fontweight='bold', fontsize=12)

plt.title("Como os clientes preferem pagar?", fontsize=16)
plt.xlabel("Participação nos Pedidos (%)")
plt.ylabel("")
plt.xlim(0, 90) # Espaço extra para o texto caber
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.show()
# Out:
# C:\Users\manub\AppData\Local\Temp\ipykernel_29960\2480450965.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Porcentagem', y='Meio de Pagamento', data=df_pag, palette='viridis')

# %%
# Célula 20: Intervalo de Confiança para o Ticket Médio

# 1. Seleciona a amostra de Ticket Médio (sem valores nulos)
ticket_medio = df_base['Ticket_Medio'].dropna()

# 2. Calcula estatísticas básicas: média, desvio padrão e tamanho da amostra
media = ticket_medio.mean()
desvio_padrao = ticket_medio.std(ddof=1)
n = len(ticket_medio)

# 3. Calcula o Intervalo de Confiança de 95% usando distribuição t de Student
ic_ticket = stats.t.interval(
    confidence=0.95,
    df=n-1,
    loc=media,
    scale=desvio_padrao / np.sqrt(n)
)

# 4. Exibe o resultado
print(f"IC 95% para o Ticket Médio: ({ic_ticket[0]:.2f}, {ic_ticket[1]:.2f})")
# Out:
# IC 95% para o Ticket Médio: (158.89, 161.64)

# %%
# Célula 21: Intervalo de Confiança para a Proporção de Atraso

# 1. Seleciona a amostra de pedidos entregues com flag de atraso
atrasado = df_logistica['Atrasado'].dropna()

# 2. Calcula a proporção média de pedidos atrasados
p = atrasado.mean()
n = len(atrasado)

# 3. Calcula o erro padrão da proporção
erro_padrao = np.sqrt(p * (1 - p) / n)

# 4. Calcula o Intervalo de Confiança de 95% para a proporção
ic_atraso = (p - 1.96 * erro_padrao, p + 1.96 * erro_padrao)

# 5. Exibe o resultado
print(f"IC 95% para Proporção de Atraso: ({ic_atraso[0]:.2%}, {ic_atraso[1]:.2%})")
# Out:
# IC 95% para Proporção de Atraso: (6.61%, 6.93%)

# %%
# Célula 22: Teste de Normalidade (Shapiro-Wilk) para o Ticket Médio

# 1. Seleciona a amostra de Ticket Médio (sem nulos)
ticket_medio_shapiro = df_base['Ticket_Medio'].dropna()

# 2. Limita a amostra para o Shapiro-Wilk se o DataFrame for muito grande (boa prática)
# O Shapiro-Wilk não é confiável ou é muito lento para N > 5000.
if len(ticket_medio_shapiro) > 5000:
    ticket_medio_shapiro = ticket_medio_shapiro.sample(5000, random_state=42)

# 3. Aplica o teste
stat, p_valor = stats.shapiro(ticket_medio_shapiro)

# 4. Exibe o p-valor e interpreta o resultado
print(f"Shapiro-Wilk (amostra de N={len(ticket_medio_shapiro)}) para Ticket Médio: p-valor = {p_valor:.4f}")
if p_valor > 0.05:
    print("Distribuição é aproximadamente normal (para a amostra testada).")
else:
    print("Distribuição não é normal (o que é comum em dados de vendas).")
# Out:
# Shapiro-Wilk (amostra de N=5000) para Ticket Médio: p-valor = 0.0000
# Distribuição não é normal (o que é comum em dados de vendas).

# %%
# Célula 23: Exibição dos Intervalos de Confiança em formato tabular 
ic_df = pd.DataFrame({
    'Métrica': ['Ticket Médio', 'Proporção de Atraso'],
    'IC Inferior': [ic_ticket[0], ic_atraso[0]],
    'IC Superior': [ic_ticket[1], ic_atraso[1]]
})

ic_df['IC Inferior'] = ic_df.apply(
    lambda row: f"R$ {row['IC Inferior']:.2f}" if row['Métrica'] == 'Ticket Médio' else f"{row['IC Inferior']:.2%}", axis=1
)
ic_df['IC Superior'] = ic_df.apply(
    lambda row: f"R$ {row['IC Superior']:.2f}" if row['Métrica'] == 'Ticket Médio' else f"{row['IC Superior']:.2%}", axis=1
)

print("\n--- Intervalos de Confiança (95%) ---")
# Usando to_string() para evitar dependência do 'tabulate'
print(ic_df.to_string(index=False))
# Out:
# --- Intervalos de Confiança (95%) ---
#             Métrica IC Inferior IC Superior
#        Ticket Médio   R$ 158.89   R$ 161.64
# Proporção de Atraso       6.61%       6.93%

# %%
# CÉLULA EXTRA: BOXPLOTS FINANCEIROS (VISUAL LIMPO E LEGÍVEL)
print("Gerando análise de distribuição financeira...")

sns.set_style("whitegrid")
fig, ax = plt.subplots(1, 2, figsize=(16, 7)) # Aumentei a altura para 7

# --- GRÁFICO 1: TICKET MÉDIO ---
dados_ticket = df_base[df_base['Ticket_Medio'] <= 500]

# Boxplot com cor sólida e borda preta para contraste
sns.boxplot(x=dados_ticket['Ticket_Medio'], color='#27ae60', ax=ax[0], linewidth=1.5)

ax[0].set_title('Distribuição do Ticket Médio (Corte visual: R$ 500)', fontsize=16, fontweight='bold', pad=15)
ax[0].set_xlabel('Valor do Pedido (R$)', fontsize=14)
ax[0].tick_params(labelsize=12) # Aumenta números do eixo

# Anotação da Mediana (MUDANÇA: Coloquei num box branco para garantir leitura)
mediana_ticket = df_base['Ticket_Medio'].median()
ax[0].text(
    mediana_ticket, -0.25, # Posição
    f'Mediana: R$ {mediana_ticket:.2f}', 
    ha='center', va='top',
    fontweight='bold', fontsize=13, color='#1e8449',
    bbox=dict(facecolor='white', edgecolor='#1e8449', boxstyle='round,pad=0.4')
)

# --- GRÁFICO 2: DESCONTO ---
sns.boxplot(x=df_base['Desconto_Perc'], color='#8e44ad', ax=ax[1], linewidth=1.5)

ax[1].set_title('Distribuição de Descontos (%)', fontsize=16, fontweight='bold', pad=15)
ax[1].set_xlabel('Desconto Concedido (%)', fontsize=14)
ax[1].tick_params(labelsize=12)

# Nota explicativa (MUDANÇA: Texto maior e mais bem posicionado)
ax[1].text(
    0.5, 0.2, 
    "Insight:\nA concentração em 0% confirma\na política de preço fixo.", 
    transform=ax[1].transAxes, 
    ha='center', fontsize=13, color='#4a4a4a',
    bbox=dict(facecolor='#f5f6fa', edgecolor='gray', boxstyle='round,pad=0.5', alpha=0.9)
)

# Título Geral (Com mais espaço no topo)
plt.suptitle("Análise de Outliers: Financeiro", fontsize=20, fontweight='bold', y=0.98)

# Ajuste fino de margens (evita sobreposição)
plt.tight_layout(rect=[0, 0, 1, 0.92]) 
plt.show()
# Out:
# Gerando análise de distribuição financeira...

# %%
# CÉLULA 24: EDA DE LOGÍSTICA (HISTOGRAMAS E BOXPLOTS OBRIGATÓRIOS)
import matplotlib.pyplot as plt
import seaborn as sns

print("Gerando análise de distribuição logística (Histogramas + Boxplots)...")

sns.set_style("whitegrid")
fig, ax = plt.subplots(2, 2, figsize=(16, 10))

# --- LINHA 1: PRAZO DE ENTREGA (LEAD TIME) ---
# Filtramos dados extremos (> 50 dias) só para o gráfico ficar legível
dados_lead = df_logistica[df_logistica['Prazo_Entrega_Dias'] <= 50]

# 1. Histograma (Esquerda)
sns.histplot(data=dados_lead, x='Prazo_Entrega_Dias', kde=True, bins=30, color='#2c3e50', ax=ax[0,0])
ax[0,0].set_title('Distribuição do Prazo de Entrega', fontsize=14, fontweight='bold')
ax[0,0].set_xlabel('Dias Corridos')

# 2. Boxplot (Direita) - OBRIGATÓRIO
sns.boxplot(x=dados_lead['Prazo_Entrega_Dias'], color='#34495e', ax=ax[0,1])
ax[0,1].set_title('Boxplot: Identificação de Outliers (Prazo)', fontsize=14, fontweight='bold')
ax[0,1].set_xlabel('Dias Corridos')

# --- LINHA 2: ATRASO (DELAY) ---
# Filtramos visualmente entre -20 e +20 dias
dados_delay = df_logistica[df_logistica['Atraso_Dias'].between(-20, 20)]

# 3. Histograma (Esquerda)
# Pintamos de vermelho quem atrasou (>0) e verde quem adiantou (<0)
sns.histplot(data=dados_delay, x='Atraso_Dias', kde=True, bins=40, color='gray', ax=ax[1,0])
ax[1,0].axvline(0, color='red', linestyle='--') # Linha do prazo
ax[1,0].set_title('Distribuição de Atraso (Negativo = Adiantado)', fontsize=14, fontweight='bold')
ax[1,0].set_xlabel('Dias de Diferença (Real - Previsto)')

# 4. Boxplot (Direita) - OBRIGATÓRIO
sns.boxplot(x=dados_delay['Atraso_Dias'], color='#e74c3c', ax=ax[1,1])
ax[1,1].axvline(0, color='black', linestyle='--')
ax[1,1].set_title('Boxplot: Variação do Atraso', fontsize=14, fontweight='bold')
ax[1,1].set_xlabel('Dias de Diferença')

plt.suptitle("Análise Descritiva Logística: Histogramas e Boxplots", fontsize=18, y=0.95)
plt.tight_layout(rect=[0, 0, 1, 0.95]) # Ajusta espaço para o título
plt.show()
# Out:
# Gerando análise de distribuição logística (Histogramas + Boxplots)...

# %%
# CÉLULA 25: EVOLUÇÃO DA RECEITA (DESIGN MODERNO / FINTECH STYLE)
import matplotlib.dates as mdates
import matplotlib.ticker as mtick

# 1. Preparação dos dados
receita_mensal = df_base.set_index('Data_Compra').resample('M')['Valor_Total_Pago'].sum().reset_index()

# 2. Configuração de Estilo "Clean"
sns.set_style("white") # Remove o fundo cinza/quadriculado pesado
fig, ax = plt.subplots(figsize=(14, 7))

# Cores Personalizadas (Paleta Moderna)
COR_LINHA = '#4834d4' # Roxo Profundo (Blurple)
COR_PREENCHIMENTO = '#686de0' # Roxo mais claro
COR_DESTAQUE = '#eb4d4b' # Vermelho Suave

# 3. Plotagem com Efeito de Área Suave
# A linha principal
ax.plot(
    receita_mensal['Data_Compra'], 
    receita_mensal['Valor_Total_Pago'], 
    color=COR_LINHA, 
    linewidth=3,
    zorder=3
)

# O preenchimento embaixo (dá peso visual sem poluir)
ax.fill_between(
    receita_mensal['Data_Compra'], 
    receita_mensal['Valor_Total_Pago'], 
    color=COR_PREENCHIMENTO, 
    alpha=0.2 # Bem transparente para ficar chique
)

# 4. Efeito "Glow" (Brilho) no Pico da Black Friday
pico = receita_mensal.loc[receita_mensal['Valor_Total_Pago'].idxmax()]

# Criamos 3 bolinhas uma em cima da outra com transparências diferentes para parecer um brilho
ax.scatter(pico['Data_Compra'], pico['Valor_Total_Pago'], s=500, color=COR_DESTAQUE, alpha=0.1, zorder=1) # Halo grande
ax.scatter(pico['Data_Compra'], pico['Valor_Total_Pago'], s=200, color=COR_DESTAQUE, alpha=0.3, zorder=2) # Halo médio
ax.scatter(pico['Data_Compra'], pico['Valor_Total_Pago'], s=50, color=COR_DESTAQUE, alpha=1.0, zorder=4, edgecolor='white', linewidth=2) # Ponto central

# 5. Anotação Estilizada (Caixa flutuante)
texto_valor = f"R$ {pico['Valor_Total_Pago']/1e6:.1f} Milhões"
ax.annotate(
    f"BLACK FRIDAY 2017\n{texto_valor}",
    xy=(pico['Data_Compra'], pico['Valor_Total_Pago']),
    xytext=(0, 40), textcoords='offset points', # Joga o texto pra cima do ponto
    ha='center', va='bottom',
    fontsize=11, fontweight='bold', color='white',
    bbox=dict(boxstyle="round,pad=0.5", fc=COR_DESTAQUE, ec="none", alpha=0.9) # Caixinha vermelha arredondada
)

# 6. Formatação Limpa dos Eixos
# Tira as bordas feias (esquerda, cima, direita)
sns.despine(left=True, bottom=False)

# Grade horizontal bem fina, apenas para guia
ax.grid(axis='y', linestyle=':', alpha=0.4, color='gray')

# Eixo Y formatado (R$ M)
def formata_milhoes(x, pos):
    if x == 0: return ''
    return f'R$ {x/1e6:.1f}M'
ax.yaxis.set_major_formatter(mtick.FuncFormatter(formata_milhoes))
ax.tick_params(axis='y', length=0) # Remove os tracinhos do eixo Y

# Eixo X formatado (Datas)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b/%y'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2)) # A cada 2 meses
plt.xticks(rotation=0, color='#636e72') 

# 7. Títulos com Hierarquia Visual
plt.text(x=receita_mensal['Data_Compra'].min(), y=receita_mensal['Valor_Total_Pago'].max()*1.15, 
         s="Sazonalidade da Receita Total", 
         fontsize=20, weight='bold', color="#5B5A5A")

plt.text(x=receita_mensal['Data_Compra'].min(), y=receita_mensal['Valor_Total_Pago'].max()*1.08, 
         s=" ", 
         fontsize=12, color='#636e72')

plt.show()
# Out:
# C:\Users\manub\AppData\Local\Temp\ipykernel_29960\3897789072.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   receita_mensal = df_base.set_index('Data_Compra').resample('M')['Valor_Total_Pago'].sum().reset_index()

# %%
# CÉLULA 26: HEATMAP DE CORRELAÇÃO (FOCADO EM ENTENDIMENTO)
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Selecionar e Traduzir Colunas
df_corr = df_base[['Receita_Bruta', 'Frete_Total', 'Ticket_Medio', 'Desconto_Perc', 'Proporcao_Frete_Perc']].copy()
df_corr.columns = ['Receita Total', 'Custo de Frete', 'Ticket Médio', '% Desconto', '% do Frete no Total']

# 2. Calcular Correlação
corr = df_corr.corr()

# 3. Visualização Limpa
plt.figure(figsize=(10, 8))
sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap="RdBu_r", # Vermelho (Ruim) a Azul (Bom)
    vmin=-1, vmax=1,
    linewidths=1,
    annot_kws={"size": 12, "weight": "bold"}
)

plt.title("O que influencia o que? (Correlação das Variáveis)", fontsize=16, pad=20)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.show()

# %%
# CÉLULA 27: RANKING DE PREÇO (VISUAL AJUSTADO)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Preparação dos dados (Top 8 Categorias)
# Garantimos que a tabela elasticidade_categoria existe (do passo anterior)
df_ranking = elasticidade_categoria.sort_values('Qtd_Pedidos', ascending=False).head(8).copy()
df_ranking = df_ranking.sort_values('Ticket_Medio_R', ascending=False)

plt.figure(figsize=(12, 8)) # Aumentei um pouco a altura para caber o texto

# 2. Plotagem
ax = sns.barplot(
    data=df_ranking,
    y='Categoria_Limpa',
    x='Ticket_Medio_R',
    palette='ch:s=.25,rot=-.25', # Degradê Azul/Roxo elegante
    edgecolor='none'
)

# 3. Anotação dos Valores
for i, p in enumerate(ax.patches):
    largura = p.get_width()
    ax.text(
        largura + 2, # Posição X
        p.get_y() + p.get_height()/2, # Posição Y
        f"R$ {largura:.0f}", 
        va='center', fontweight='bold', fontsize=12, color='#4a4a4a'
    )

# 4. Títulos e Subtítulos (A CORREÇÃO DO SOBRESCRITO ESTÁ AQUI)
# Título Principal (Mais alto, y=1.1)
plt.title("Ticket Médio das Principais Categorias", fontsize=20, loc='left', y=1.1, fontweight='bold', color='#2d3436')

# Nota Explicativa (Posicionada exatamente entre o título e o gráfico)
ax.text(
    x=0, 
    y=1.03, # Um pouco acima do gráfico, mas abaixo do título
    s="Nota: A análise revelou que estas categorias não praticam descontos (Média de Desconto: 0.0%)", 
    transform=ax.transAxes, 
    fontsize=11, 
    color='#e15f41', # Laranja destaque
    fontweight='bold'
)

# 5. Limpeza Visual
sns.despine(left=True, bottom=True)
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_xticks([])
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\manub\AppData\Local\Temp\ipykernel_29960\1553730902.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
# CÉLULA 28: SAZONALIDADE (SMALL MULTIPLES - VERSÃO FINAL CORRIGIDA)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import matplotlib.dates as mdates

# --- 1. LIMPEZA DE DADOS ---
# Recalcula para garantir que as variáveis existem
df_base['Ano_Mes'] = df_base['Data_Compra'].dt.to_period('M')
sazonalidade_uf = df_base.groupby(['Ano_Mes', 'UF_Cliente'])['Receita_Bruta'].sum().reset_index()

# Filtrar Top 5
top_ufs = df_base.groupby('UF_Cliente')['Receita_Bruta'].sum().nlargest(5).index.tolist()
df_plot = sazonalidade_uf[sazonalidade_uf['UF_Cliente'].isin(top_ufs)].copy()
df_plot['Data_Plot'] = df_plot['Ano_Mes'].dt.to_timestamp()

# Remove o último mês incompleto
ultimo_mes_real = df_plot['Data_Plot'].max()
df_plot = df_plot[df_plot['Data_Plot'] < ultimo_mes_real]

# --- 2. CONFIGURAÇÃO VISUAL ---
sns.set_style("whitegrid")

g = sns.relplot(
    data=df_plot,
    x='Data_Plot',
    y='Receita_Bruta',
    col='UF_Cliente', 
    col_wrap=3,
    kind='line',
    height=4,
    aspect=1.4,
    linewidth=3,
    marker='o',
    facet_kws={'sharey': False}
)

# --- 3. CUSTOMIZAÇÃO ---
cores_map = {'SP': '#2980b9', 'RJ': '#c0392b', 'MG': '#d35400', 'RS': '#8e44ad', 'PR': '#27ae60'}

for ax in g.axes.flat:
    # Títulos
    titulo_atual = ax.get_title()
    uf_nome = titulo_atual.split('=')[-1].strip()
    ax.set_title(f"{uf_nome}", fontsize=16, fontweight='bold', color=cores_map.get(uf_nome, 'black'))
    
    # Cores
    if ax.lines:
        line = ax.lines[0]
        line.set_color(cores_map.get(uf_nome, 'black'))
    
    # Eixos
    ax.yaxis.set_major_formatter(mtick.FuncFormatter(lambda x, p: f'R$ {x/1000:.0f}K'))
    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=6))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b/%y'))
    
    ax.tick_params(axis='both', which='major', labelsize=11)
    
    # --- CORREÇÃO DO ERRO AQUI ---
    # Removemos 'b=False' e usamos o método direto do eixo X
    ax.xaxis.grid(False) 

# --- 4. AJUSTES FINAIS ---
g.fig.subplots_adjust(top=0.85, hspace=0.4, wspace=0.3)

g.fig.suptitle("Performance Regional: Tendência de Vendas por Estado", 
               fontsize=22, fontweight='bold', y=0.98, color='#2c3e50')

g.fig.text(0.5, 0.92, 
           "Nota: Escalas verticais independentes para visualizar a curva de cada UF separadamente.", 
           ha='center', fontsize=12, color='gray')

g.set_axis_labels("", "")

plt.show()

# %%
# CÉLULA 29: CAUSA RAIZ DE ATRASO (DEGRADÊ DE ALERTA)
# 1. Dados (Mantemos a mesma lógica de filtrar volume > 1000)
df_atraso = df_logistica.groupby('UF_Cliente').agg(
    Total=('ID_Pedido', 'count'),
    Taxa_Atraso=('Atrasado', 'mean')
).query('Total > 1000').sort_values('Taxa_Atraso', ascending=False).head(10)

# 2. Plotagem
plt.figure(figsize=(12, 6))

# AQUI ESTÁ A MUDANÇA:
# Usamos palette='Reds_r' para criar o degradê do vermelho escuro (pior) para o claro
# hue=df_atraso.index é necessário nas versões novas do Seaborn para aplicar cores diferentes
ax = sns.barplot(
    x=df_atraso.index, 
    y=df_atraso['Taxa_Atraso'], 
    palette='Reds_r',
    hue=df_atraso.index, # Garante o degradê por estado
    legend=False         # Remove a legenda lateral desnecessária
)

# 3. Formatação do Eixo Y em Porcentagem
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

# 4. Rótulos em cima das barras (mantivemos igual pois ficou bom)
for p in ax.patches:
    # Verificação de segurança para não etiquetar barras vazias (bug comum do matplotlib)
    if p.get_height() > 0:
        ax.annotate(f"{p.get_height():.1%}",
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='bottom', fontsize=11, fontweight='bold', color='#2d3436')

plt.title("Top 10 Estados com maior proporção de atraso (Pedidos > 1000))", fontsize=16)
plt.ylabel("% de Pedidos Atrasados")
plt.xlabel("Estado")
plt.ylim(0, 0.16) # Mantém o respiro visual no topo
plt.show()
